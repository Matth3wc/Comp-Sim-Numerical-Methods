# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# B: Numerical accuracy

# %% [markdown]
# Dealing With Floating Point Numbers

# %% [markdown]
# Question 1 section 1.3
#
# Write a program that determines your computers underflow limits and overflow limits.(Within a factor of two)

# %%
def determine_underflow():
    under = 1.0
    over = 1.0
    while under/2!=0 or np.isfinite(over*2):
        if under/2!=0:
            under /= 2
            
        
        if  np.isfinite(over*2):
            over *= 2
        
    return under, over

# %%
determine_underflow()
# Out:
# (5e-324, 8.98846567431158e+307)

# %% [markdown]
# Question 2 section 1.3

# %% [markdown]
# Numerical Derivatives

# %% [markdown]
# Question 1a section 1.4

# %% [markdown]
# Question 1b section 1.4

# %%
"""
PYU33C01 Assignment 1: Iterations and Numerical Accuracy
Student Name: [Your Name]
Student Number: [Your Student Number]
Date: October 6, 2025
"""

import numpy as np
import matplotlib.pyplot as plt
import sys

# Display student information
print("=" * 50)
print("PYU33C01 Assignment 1")
print("Student Name: [Your Name]")
print("Student Number: [Your Student Number]")
print("=" * 50)
print()

# ============================================================================
# SECTION A: HERON'S ROOT FINDING METHOD
# ============================================================================

print("SECTION A: HERON'S ROOT FINDING METHOD")
print("=" * 50)
print()

# Part 1: Implementation
def heron_root(a, x_0, n):
    x_n = x_0
    for _ in range(n):
        x_n = 0.5 * (x_n + a / x_n)
    return x_n

sqrt_2 = heron_root(2, 1, 10)
print(f"Approximation of x=√2 using Heron's method: {sqrt_2}")
print(f"NumPy sqrt(2): {np.sqrt(2)}")
print(f"Difference: {abs(sqrt_2 - np.sqrt(2))}")
print()

# Part 2: Plot x_n as a function of iteration number
x_0_array = np.array([0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25])
n_array = np.arange(1, len(x_0_array)+1)

plt.figure(figsize=(8, 6)) 
for j in range(len(x_0_array)):

    heron_root_array = []
    markers = ['o', 's', '^', 'D', 'x', 'P', 'v', '>'] 

    x_0 = x_0_array[j]

    heron_root_array = np.array([heron_root(2, x_0, n-1) for n in n_array])

    line, = plt.plot(n_array, heron_root_array, linewidth=1, label=fr"$x_0$ = {x_0}")

    
    plt.plot(n_array, heron_root_array, linestyle='None',
             marker=markers[j],
             color=line.get_color(),)
        
    print(f"x_0 = {x_0}: {heron_root_array}")

plt.xlabel(f'Iteration number (n)')
plt.ylabel('Approximation of $\sqrt{2}$')
plt.title("Convergence of Heron's Method to $x=\sqrt{2}$")
plt.axhline(y=np.sqrt(2), color='r', linestyle='--', label='np.sqrt(2) result')
plt.xlim(1, 5)
plt.ylim(0, 2.5)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('herons_convergence.png', dpi=300, bbox_inches='tight')
plt.show()

print()

# Part 3: Plot relative error for x_n × x_n
def heron_square_error(a, x_0, n):
    x_n = heron_root(a, x_0, n)
    error = abs((x_n**2 - a) / a)
    return error

plt.figure(figsize=(8, 6)) 
for j in range(len(x_0_array)):

    heron_square_error_array = []
    markers = ['o', 's', '^', 'D', 'x', 'P', 'v', '>'] 

    x_0 = x_0_array[j]

    heron_square_error_array = np.array([heron_square_error(2, x_0, n) for n in n_array])

    line, = plt.plot(n_array, heron_square_error_array, linewidth=1, label=fr"$x_0$ = {x_0}")

    
    plt.plot(n_array, heron_square_error_array, linestyle='None',
             marker=markers[j],
             color=line.get_color(),)
        
    print(f"x_0 = {x_0}, Errors: {heron_square_error_array}")

plt.xlabel(f'Iteration number (n)')
plt.ylabel('Relative error $\\frac{|x_n^2 - a|}{a}$')
plt.title("Relative error in Heron's Method for $\sqrt{2}$")
plt.yscale('log')
plt.xlim(1, 7)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('herons_error.png', dpi=300, bbox_inches='tight')
plt.show()

print()
print()

# ============================================================================
# SECTION B: NUMERICAL ACCURACY
# ============================================================================

print("SECTION B: NUMERICAL ACCURACY")
print("=" * 50)
print()

# Section 1.3: Dealing with Floating Point Numbers
print("1.3 DEALING WITH FLOATING POINT NUMBERS")
print("-" * 50)
print()

# Question 1a: Underflow limit
print("Question 1a: Underflow Limit")
print("Finding smallest positive floating point number...")
print()

x = 1.0
underflow_limit = x
iteration = 0

while x / 2.0 > 0:
    underflow_limit = x
    x = x / 2.0
    iteration += 1

print(f"Underflow limit: {underflow_limit:.5e}")
print(f"Reached after {iteration} iterations")
print(f"System float info (min): {sys.float_info.min:.5e}")
print()

# Question 1b: Overflow limit
print("Question 1b: Overflow Limit")
print("Finding largest positive floating point number...")
print()

x = 1.0
overflow_limit = x
iteration = 0

while x * 2.0 < float('inf'):
    overflow_limit = x
    x = x * 2.0
    iteration += 1

print(f"Overflow limit: {overflow_limit:.5e}")
print(f"Reached after {iteration} iterations")
print(f"System float info (max): {sys.float_info.max:.5e}")
print()

# Question 2: Machine precision
print("Question 2: Machine Precision (epsilon)")
print("Finding smallest eps such that 1.0 + eps != 1.0...")
print()

eps = 1.0
machine_precision = eps
iteration = 0

while (1.0 + eps / 2.0) != 1.0:
    machine_precision = eps
    eps = eps / 2.0
    iteration += 1

print(f"Machine precision (epsilon): {machine_precision:.5e}")
print(f"Reached after {iteration} iterations")
print(f"System float info (epsilon): {sys.float_info.epsilon:.5e}")
print()
print()

# Section 1.4: Numerical Derivatives
print("1.4 NUMERICAL DERIVATIVES")
print("-" * 50)
print()

def f(x):
    """Function to differentiate: f(x) = x(x-1)"""
    return x * (x - 1)

def analytical_derivative(x):
    """Analytical derivative: f'(x) = 2x - 1"""
    return 2 * x - 1

def forward_difference(f, x, h):
    """Forward difference approximation: [f(x+h) - f(x)]/h"""
    return (f(x + h) - f(x)) / h

def central_difference(f, x, h):
    """Central difference approximation: [f(x+h) - f(x-h)]/(2h)"""
    return (f(x + h) - f(x - h)) / (2 * h)

# Question 1a: Compare forward and central differences
print("Question 1a: Forward vs Central Difference")
print()

x_point = 1.0
true_derivative = analytical_derivative(x_point)
h_values = np.logspace(-1, -16, 100)  # h from 10^-1 to 10^-16

forward_errors = []
central_errors = []

for h in h_values:
    forward_deriv = forward_difference(f, x_point, h)
    central_deriv = central_difference(f, x_point, h)
    
    forward_error = abs(forward_deriv - true_derivative)
    central_error = abs(central_deriv - true_derivative)
    
    forward_errors.append(forward_error)
    central_errors.append(central_error)

forward_errors = np.array(forward_errors)
central_errors = np.array(central_errors)

print(f"Function: f(x) = x(x-1) at x = {x_point}")
print(f"True derivative: f'({x_point}) = {true_derivative}")
print()

# Plot the errors
plt.figure(figsize=(10, 6))
plt.loglog(h_values, forward_errors, 'b-', label='Forward Difference', linewidth=2)
plt.loglog(h_values, central_errors, 'r-', label='Central Difference', linewidth=2)
plt.axhline(y=machine_precision, color='g', linestyle='--', 
            label=f'Machine Precision ({machine_precision:.2e})', linewidth=1.5)

# Add reference lines for expected behavior
h_squared = h_values**2
plt.loglog(h_values, h_values * 1e-1, 'b:', alpha=0.5, label='$\propto h$ (forward)')
plt.loglog(h_values, h_squared * 1e1, 'r:', alpha=0.5, label='$\propto h^2$ (central)')

plt.xlabel('Step size h')
plt.ylabel('Absolute error in derivative')
plt.title(f"Numerical Derivative Error for f(x) = x(x-1) at x = {x_point}")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('numerical_derivatives.png', dpi=300, bbox_inches='tight')
plt.show()

# Question 1b: Can we achieve machine precision accuracy?
print("Question 1b: Achieving Machine Precision")
print("=" * 50)
print()

# Find optimal h for central difference
min_central_idx = np.argmin(central_errors)
optimal_h_central = h_values[min_central_idx]
min_central_error = central_errors[min_central_idx]

print(f"Central Difference Method:")
print(f"  Optimal h: {optimal_h_central:.5e}")
print(f"  Minimum error: {min_central_error:.5e}")
print(f"  Ratio to machine precision: {min_central_error / machine_precision:.2f}")
print()

# Find optimal h for forward difference
min_forward_idx = np.argmin(forward_errors)
optimal_h_forward = h_values[min_forward_idx]
min_forward_error = forward_errors[min_forward_idx]

print(f"Forward Difference Method:")
print(f"  Optimal h: {optimal_h_forward:.5e}")
print(f"  Minimum error: {min_forward_error:.5e}")
print(f"  Ratio to machine precision: {min_forward_error / machine_precision:.2f}")
print()

print("ANALYSIS:")
print("=" * 50)
if min_central_error > machine_precision:
    print(f"The numerical derivative accuracy does NOT reach machine precision.")
    print(f"")
    print(f"Best achievable accuracy: ~{min_central_error:.2e}")
    print(f"This is {min_central_error/machine_precision:.1f}x worse than machine precision.")
    print()
    print("This is due to the competing effects of:")
    print("  1. Truncation error (decreases as h → 0)")
    print("  2. Round-off error (increases as h → 0)")
    print()
    print("As h decreases:")
    print("  - Initially, truncation error dominates → error decreases")
    print("  - Eventually, round-off error dominates → error increases")
    print("  - The optimal h balances these two competing effects")
else:
    print("The numerical derivative can achieve near machine precision.")

print()
print("=" * 50)
print("All computations complete!")
print("=" * 50)
print()
print("Figures saved:")
print("  - herons_convergence.png")
print("  - herons_error.png")
print("  - numerical_derivatives.png")
# Out:
# ==================================================
# PYU33C01 Assignment 1
# Student Name: [Your Name]
# Student Number: [Your Student Number]
# ==================================================
#
# SECTION A: HERON'S ROOT FINDING METHOD
# ==================================================
#
# Approximation of x=√2 using Heron's method: 1.414213562373095
# NumPy sqrt(2): 1.4142135623730951
# Difference: 2.220446049250313e-16
#
# x_0 = 0.5: [0.5        2.25       1.56944444 1.42189036 1.41423429 1.41421356
#  1.41421356 1.41421356]
# x_0 = 0.75: [0.75       1.70833333 1.43953252 1.41443622 1.41421358 1.41421356
#  1.41421356 1.41421356]
# x_0 = 1.0: [1.         1.5        1.41666667 1.41421569 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 1.25: [1.25       1.425      1.41425439 1.41421356 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 1.5: [1.5        1.41666667 1.41421569 1.41421356 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 1.75: [1.75       1.44642857 1.41457231 1.41421361 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 2.0: [2.         1.5        1.41666667 1.41421569 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 2.25: [2.25       1.56944444 1.42189036 1.41423429 1.41421356 1.41421356
#  1.41421356 1.41421356]
# x_0 = 0.5, Errors: [1.53125000e+00 2.31577932e-01 1.08861034e-02 2.93077642e-05
#  2.14730012e-10 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 0.75, Errors: [4.59201389e-01 3.61269385e-02 3.14912112e-04 2.47846046e-08
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 1.0, Errors: [1.25000000e-01 3.47222222e-03 3.00365244e-06 2.25530705e-12
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 1.25, Errors: [1.53125000e-02 5.77341105e-05 8.33258573e-10 2.22044605e-16
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 1.5, Errors: [3.47222222e-03 3.00365244e-06 2.25530705e-12 2.22044605e-16
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 1.75, Errors: [4.60778061e-02 5.07410683e-04 6.43337568e-08 1.11022302e-15
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 2.0, Errors: [1.25000000e-01 3.47222222e-03 3.00365244e-06 2.25530705e-12
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# x_0 = 2.25, Errors: [2.31577932e-01 1.08861034e-02 2.93077642e-05 2.14730012e-10
#  2.22044605e-16 2.22044605e-16 2.22044605e-16 2.22044605e-16]
# SECTION B: NUMERICAL ACCURACY
# ==================================================
#
# 1.3 DEALING WITH FLOATING POINT NUMBERS
# --------------------------------------------------
#
# Question 1a: Underflow Limit
# Finding smallest positive floating point number...
#
# Underflow limit: 9.88131e-324
# Reached after 1074 iterations
# System float info (min): 2.22507e-308
#
# Question 1b: Overflow Limit
# Finding largest positive floating point number...
#
# Overflow limit: 4.49423e+307
# Reached after 1023 iterations
# System float info (max): 1.79769e+308
#
# Question 2: Machine Precision (epsilon)
# Finding smallest eps such that 1.0 + eps != 1.0...
#
# Machine precision (epsilon): 4.44089e-16
# Reached after 52 iterations
# System float info (epsilon): 2.22045e-16
#
#
# 1.4 NUMERICAL DERIVATIVES
# --------------------------------------------------
#
# Question 1a: Forward vs Central Difference
#
# Function: f(x) = x(x-1) at x = 1.0
# True derivative: f'(1.0) = 1.0
# Question 1b: Achieving Machine Precision
# ==================================================
#
# Central Difference Method:
#   Optimal h: 3.51119e-02
#   Minimum error: 2.22045e-16
#   Ratio to machine precision: 0.50
#
# Forward Difference Method:
#   Optimal h: 2.65609e-09
#   Minimum error: 6.87429e-09
#   Ratio to machine precision: 15479532.00
#
# ANALYSIS:
# ==================================================
# The numerical derivative can achieve near machine precision.
#
# ==================================================
# All computations complete!
# ==================================================
#
# Figures saved:
#   - herons_convergence.png
#   - herons_error.png
#   - numerical_derivatives.png
